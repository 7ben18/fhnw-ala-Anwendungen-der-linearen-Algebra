# %%
import numpy as np

# %%
M = np.array([[2,-1,0],[-1,2,-1],[0,-1,2]])
M
# Out:
# array([[ 2, -1,  0],
#        [-1,  2, -1],
#        [ 0, -1,  2]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#3a testen auf Symetrisch
# Matrix ist Syemtrsich! 
M
# Out:
# array([[ 2, -1,  0],
#        [-1,  2, -1],
#        [ 0, -1,  2]])

# %%
# positiv Definit?
eigw, eigv = np.linalg.eig(A)
display(eigw, eigv)
# Out:
# array([3.41421356, 2.        , 0.58578644])
# array([[-5.00000000e-01, -7.07106781e-01,  5.00000000e-01],
#        [ 7.07106781e-01,  4.05405432e-16,  7.07106781e-01],
#        [-5.00000000e-01,  7.07106781e-01,  5.00000000e-01]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ex = np.array([1,0,0]).reshape(3,1)
ey = np.array([0,1,0]).reshape(3,1)
ez = np.array([0,0,1]).reshape(3,1)
display(ex, ey, ez)
# Out:
# array([[1],
#        [0],
#        [0]])
# array([[0],
#        [1],
#        [0]])
# array([[0],
#        [0],
#        [1]])

# %%
np.linalg.norm(ex.T @ A @ ex)
# Out:
# 2.0
